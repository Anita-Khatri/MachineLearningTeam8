# %%
import numpy as np
import pandas as pd

# %%
# Reading the csv file adult_data.csv into dataframe
adult_data_df = pd.read_csv('adult_data.csv')

# %%
#Checking the first few rows of the dataset using the head() function
adult_data_df.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
#Checking the first few rows of the dataset using the sample() function
adult_data_df.sample(n=10)
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 31353   24   Private  125905        HS-grad              9
# 6328    20   Private  175069   Some-college             10
# 25191   39   Private  193689   Some-college             10
# 24315   53   Private   31588      Bachelors             13
# 15200   30   Private  154297           10th              6
# 30154   35   Private  283122   Some-college             10
# 4816    30   Private  112115      Bachelors             13
# 26214   24   Private  161638        HS-grad              9
# 1990    19   Private  365640        HS-grad              9
# 15646   30   Private  131588        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 31353   Married-civ-spouse        Craft-repair         Husband   White
# 6328         Never-married        Adm-clerical       Own-child   White
# 25191   Married-civ-spouse   Machine-op-inspct         Husband   White
# ...

# %%
# Examining the columns and their data types using info()
adult_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# Checking for missing values using isnull() 
adult_data_df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
#Investigating basic summary statistics with describe()
adult_data_df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#Investigating basic summary statistics with describe()
adult_data_df.describe(include= 'all').round(2)
# Out:
#              age workclass      fnlwgt education  education-num  \
# count   32561.00     32561    32561.00     32561       32561.00
# unique       NaN         9         NaN        16            NaN
# top          NaN   Private         NaN   HS-grad            NaN
# freq         NaN     22696         NaN     10501            NaN
# mean       38.58       NaN   189778.37       NaN          10.08
# std        13.64       NaN   105549.98       NaN           2.57
# min        17.00       NaN    12285.00       NaN           1.00
# 25%        28.00       NaN   117827.00       NaN           9.00
# 50%        37.00       NaN   178356.00       NaN          10.00
# 75%        48.00       NaN   237051.00       NaN          12.00
# max        90.00       NaN  1484705.00       NaN          16.00
#
#              marital-status       occupation relationship    race    sex  \
# count                 32561            32561        32561   32561  32561
# ...
